# %%
import numpy as np
import pandas as pd

# %matplotlib inline
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

import re
import string
import nltk
nltk.download('stopwords')
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
nltk.download('wordnet')
from nltk.corpus import stopwords, wordnet
from nltk.stem import WordNetLemmatizer
from nltk.tokenize import word_tokenize

from pandas_profiling import ProfileReport
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/kimginam/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to /Users/kimginam/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /Users/kimginam/nltk_data...
# [nltk_data]   Package averaged_perceptron_tagger is already up-to-
# [nltk_data]       date!
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/kimginam/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
df = pd.read_csv('/Users/kimginam/Downloads/datasets/Real or not?/train.csv')

# %%
df.head()
# Out:
#    id keyword location                                               text  \
# 0   1     NaN      NaN  Our Deeds are the Reason of this #earthquake M...
# 1   4     NaN      NaN             Forest fire near La Ronge Sask. Canada
# 2   5     NaN      NaN  All residents asked to 'shelter in place' are ...
# 3   6     NaN      NaN  13,000 people receive #wildfires evacuation or...
# 4   7     NaN      NaN  Just got sent this photo from Ruby #Alaska as ...
#
#    target
# 0       1
# 1       1
# 2       1
# 3       1
# 4       1

# %%
df['token_text'] = df['text'].apply(word_tokenize)

# %%
df['lemma_str'] = [' '.join(map(str, l)) for l in df['token_text']]

# %%
df
# Out:
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target  \
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# ...

# %%
def addition(n):
    return n * 3

add = (3, 4)
result = map(addition, add)
print(list(result))
# Out:
# [9, 12]

# %%
dfff = pd.DataFrame(df['text'].value_counts())

# %%
dfff
# Out:
#                                                     text
# 11-Year-Old Boy Charged With Manslaughter of To...    10
# #Bestnaijamade: 16yr old PKK suicide bomber who...     6
# The Prophet (peace be upon him) said 'Save your...     6
# He came to a land which was engulfed in tribal ...     6
# Madhya Pradesh Train Derailment: Village Youth ...     5
# ...                                                  ...
# Leicester_Merc : ICYMI - #Ashes 2015: Australia...     1
# '60 all out? What!' - World reacts to Aussie co...     1
# Strengthening partnerships #AfterHaiyan http://...     1
# @RomeoCrow Most welcome! Organizing Twitter to ...     1
# Drought fuels bush fires in Jamaica - http://t....     1
#
# [7503 rows x 1 columns]

# %%
dfff['asd'] = dfff.index

# %%
dfff
# Out:
#                                                     text  \
# 11-Year-Old Boy Charged With Manslaughter of To...    10
# #Bestnaijamade: 16yr old PKK suicide bomber who...     6
# The Prophet (peace be upon him) said 'Save your...     6
# He came to a land which was engulfed in tribal ...     6
# Madhya Pradesh Train Derailment: Village Youth ...     5
# ...                                                  ...
# Leicester_Merc : ICYMI - #Ashes 2015: Australia...     1
# '60 all out? What!' - World reacts to Aussie co...     1
# Strengthening partnerships #AfterHaiyan http://...     1
# @RomeoCrow Most welcome! Organizing Twitter to ...     1
# Drought fuels bush fires in Jamaica - http://t....     1
#
#                                                                                                   asd
# 11-Year-Old Boy Charged With Manslaughter of To...  11-Year-Old Boy Charged With Manslaughter of T...
# ...

# %%
dfff.columns = ['counts', 'words']

# %%
dfff
# Out:
#                                                     counts  \
# 11-Year-Old Boy Charged With Manslaughter of To...      10
# #Bestnaijamade: 16yr old PKK suicide bomber who...       6
# The Prophet (peace be upon him) said 'Save your...       6
# He came to a land which was engulfed in tribal ...       6
# Madhya Pradesh Train Derailment: Village Youth ...       5
# ...                                                    ...
# Leicester_Merc : ICYMI - #Ashes 2015: Australia...       1
# '60 all out? What!' - World reacts to Aussie co...       1
# Strengthening partnerships #AfterHaiyan http://...       1
# @RomeoCrow Most welcome! Organizing Twitter to ...       1
# Drought fuels bush fires in Jamaica - http://t....       1
#
#                                                                                                 words
# 11-Year-Old Boy Charged With Manslaughter of To...  11-Year-Old Boy Charged With Manslaughter of T...
# ...

# %%
dfff = dfff.reset_index().drop('index', axis=1)

# %%
dfff
# Out:
#       counts                                              words
# 0         10  11-Year-Old Boy Charged With Manslaughter of T...
# 1          6  #Bestnaijamade: 16yr old PKK suicide bomber wh...
# 2          6  The Prophet (peace be upon him) said 'Save you...
# 3          6  He came to a land which was engulfed in tribal...
# 4          5  Madhya Pradesh Train Derailment: Village Youth...
# ...      ...                                                ...
# 7498       1  Leicester_Merc : ICYMI - #Ashes 2015: Australi...
# 7499       1  '60 all out? What!' - World reacts to Aussie c...
# 7500       1  Strengthening partnerships #AfterHaiyan http:/...
# 7501       1  @RomeoCrow Most welcome! Organizing Twitter to...
# 7502       1  Drought fuels bush fires in Jamaica - http://t...
#
# [7503 rows x 2 columns]
